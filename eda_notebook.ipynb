# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd. read_csv('/content/Churn_Modelling.csv')

# %%
import pandas as pd        # For data manipulation and analysis
import numpy as np         # For numerical operations
import matplotlib.pyplot as plt  # For plotting
import seaborn as sns      # For advanced data visualization

df = pd.read_csv('/content/Churn_Modelling.csv')  # Load dataset into DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df. describe(). round (2)
# Out:
#        RowNumber   CustomerId  CreditScore       Age    Tenure    Balance  \
# count   10000.00     10000.00     10000.00  10000.00  10000.00   10000.00
# mean     5000.50  15690940.57       650.53     38.92      5.01   76485.89
# std      2886.90     71936.19        96.65     10.49      2.89   62397.41
# min         1.00  15565701.00       350.00     18.00      0.00       0.00
# 25%      2500.75  15628528.25       584.00     32.00      3.00       0.00
# 50%      5000.50  15690738.00       652.00     37.00      5.00   97198.54
# 75%      7500.25  15753233.75       718.00     44.00      7.00  127644.24
# max     10000.00  15815690.00       850.00     92.00     10.00  250898.09
#
#        NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary   Exited
# count       10000.00   10000.00        10000.00         10000.00  10000.0
# mean            1.53       0.71            0.52        100090.24      0.2
# std             0.58       0.46            0.50         57510.49      0.4
# ...

# %%
new_df = pd.DataFrame(df, columns=['Age', 'Tenure'])

# %%
new_df.head()
# Out:
#    Age  Tenure
# 0   42       2
# 1   41       1
# 2   42       8
# 3   39       1
# 4   43       2
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Tenure'].plot(kind='hist', bins=20, title='Tenure')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='Age', y='Tenure', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
# ...

# %%
new_df['Age'] = new_df['Age'].fillna(new_df['Age'].mean())

# %%
new_df.( info)
# Out:
#   File "/tmp/ipython-input-17-3891760622.py", line 1
#     new_df.( info)
#            ^
# SyntaxError: invalid syntax

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     10000 non-null  int64
#  1   Tenure  10000 non-null  int64
# dtypes: int64(2)
# memory usage: 156.4 KB

# %%
scaler = MinMaxScaler() #Instantiating the MinMaxScal
normalized_df = scaler.fit_transform(new_df)
print(normalized_df)
# Out:
# [[0.32432432 0.2       ]
#  [0.31081081 0.1       ]
#  [0.32432432 0.8       ]
#  ...
#  [0.24324324 0.7       ]
#  [0.32432432 0.3       ]
#  [0.13513514 0.4       ]]

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

x_array = np.array([[2], [3], [5], [6], [6]])

scaler = MinMaxScaler()  # Correct class name
normalized_arr = scaler.fit_transform(x_array)

print(normalized_arr)
# Out:
# [[0.  ]
#  [0.25]
#  [0.75]
#  [1.  ]
#  [1.  ]]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()  # Instantiate the scaler
standardized_df = scaler.fit_transform(new_df)  # Apply to new_df

print(standardized_df)
# Out:
# [[ 0.29351742 -1.04175968]
#  [ 0.19816383 -1.38753759]
#  [ 0.29351742  1.03290776]
#  ...
#  [-0.27860412  0.68712986]
#  [ 0.29351742 -0.69598177]
#  [-1.04143285 -0.35020386]]

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

x_array = np.array([[2], [3], [5], [6], [6]])

scaler = StandardScaler()  # Correct spelling
normalized_arr_ss = scaler.fit_transform(x_array)

print(normalized_arr_ss)
# Out:
# [[-1.47709789]
#  [-0.86164044]
#  [ 0.36927447]
#  [ 0.98473193]
#  [ 0.98473193]]

# %%
df = pd.read_csv('/content/raw_sales2.csv')

# %%
df.head(

)
# Out:
#               datesold  postcode   price propertyType  bedrooms
# 0  2007-02-07 00:00:00      2607  525000        house         4
# 1  2007-02-27 00:00:00      2906  290000        house         3
# 2  2007-03-07 00:00:00      2905  328000        house         3
# 3  2007-03-09 00:00:00      2905  380000        house         4
# 4  2007-03-21 00:00:00      2906  310000        house         3

# %%
type(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-25-2009485777.py in <cell line: 0>()
# ----> 1 type(data)
#
# NameError: name 'data' is not defined

# %%
type(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-26-1624561448.py in <cell line: 0>()
# ----> 1 type(data)
#
# NameError: name 'data' is not defined

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
import statistics

def find_anomalies(data):
    # Define a list to accumulate anomalies
    anomalies = []

    # Calculate mean and standard deviation
    random_data_std = statistics.stdev(data)
    random_data_mean = statistics.mean(data)

    # Set cutoff for 3 standard deviations
    anomaly_cut_off = random_data_std * 3
    lower_limit = random_data_mean - anomaly_cut_off
    upper_limit = random_data_mean + anomaly_cut_off

    # Generate list of anomalies
    for outlier in data:
        if outlier > upper_limit or outlier < lower_limit:
            anomalies.append(outlier)

    return anomalies

# %%
print(df['price'])
# Out:
# 0        525000
# 1        290000
# 2        328000
# 3        380000
# 4        310000
#           ...
# 29575    500000
# 29576    560000
# 29577    464950
# 29578    589000
# 29579    775000
# Name: price, Length: 29580, dtype: int64

# %%
list_1 = find_anomalies(data[ 'price'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-31-3352637976.py in <cell line: 0>()
# ----> 1 list_1 = find_anomalies(data[ 'price'])
#
# NameError: name 'data' is not defined

# %%
list_1 = find_anomalies(df['price'])
print(list_1)
# Out:
# [1530000, 1780000, 1460000, 3500000, 2100000, 1580000, 2600000, 1875000, 2200000, 1620000, 1562500, 2350000, 1580000, 7300000, 1670000, 1780000, 2400000, 1530000, 1567140, 1700000, 1675000, 2060000, 1750000, 1500000, 1725000, 1455000, 2000000, 1475000, 4150000, 1780000, 1650000, 2500000, 5425000, 2200000, 2375000, 2100000, 1950000, 1980000, 1525000, 1900000, 1460000, 1500000, 1500000, 2760000, 1550000, 1605000, 1730000, 1650000, 1575000, 1530000, 1510000, 1501000, 1880000, 1620000, 1650000, 1470000, 1495000, 1600000, 1910000, 1485000, 1965000, 1640000, 1777500, 1500000, 1480000, 1650000, 1625000, 1540000, 2600000, 1900000, 3160000, 1975000, 1555000, 1900000, 1785000, 1701000, 1510000, 2080000, 3400000, 2050000, 1510000, 2550000, 1900000, 1801000, 1950000, 3400000, 1650000, 1915000, 1870000, 1560000, 2400000, 2090000, 1490000, 1670000, 1550000, 1560000, 1700000, 1800000, 1900000, 1710000, 1475000, 2125000, 1600000, 1675000, 1952500, 1670000, 1665000, 2150000, 1460000, 1715000, 1750000
# ...

# %%
len (list_1)
# Out:
# 461

# %%
len(df)
# Out:
# 29580

# %%
data.price.skew()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-35-201359490.py in <cell line: 0>()
# ----> 1 data.price.skew()
#
# NameError: name 'data' is not defined

# %%
df.price.skew()
# Out:
# np.float64(4.312009366902366)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.kdeplot(df.price)
plt.title("Price Distribution with KDE")
plt.xlabel("Price")
plt.ylabel("Density")
plt.show()

# %%
data = df

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=data)
plt.xticks(rotation=45)  # Rotate x-axis labels if there are many columns
plt.title("Boxplot of All Numeric Columns")
plt.show()

# %%
# Step 1: Install Git (usually already available)
# !git --version
# Out:
# git version 2.34.1

# %%
# Step 2: Configure Git with your name and email
# !git config --global user.name "exploratory-data-analysis."
# !git config --global user.email "daljeetkaur9570@gmail.com"

# %%
# Save your notebook to local Colab directory
filename = "eda_notebook.ipynb"
from google.colab import files
  # Optional backup

# %%
# !git clone https://github.com/prince545/exploratory-data-analysis.git
# Out:
# Cloning into 'exploratory-data-analysis'...
# ...

# %%
# !cp /content/eda_notebook.ipynb /content/exploratory-data-analysis/
# Out:
# cp: cannot stat '/content/eda_notebook.ipynb': No such file or directory

# %%
# !find /content -name "*.ipynb"

# %%
# !cp eda_notebook.ipynb exploratory-data-analysis/
# Out:
# cp: cannot stat 'eda_notebook.ipynb': No such file or directory

# %%
git init
# Out:
#   File "/tmp/ipython-input-54-663072818.py", line 1
#     git init
#         ^
# SyntaxError: invalid syntax

# %%
# %cd /content
# !mkdir exploratory-data-analysis
# %cd exploratory-data-analysis
# Out:
# /content
# mkdir: cannot create directory ‘exploratory-data-analysis’: File exists
# /content/exploratory-data-analysis

# %%
# !git init
# !git remote add origin https://github.com/prince545/exploratory-data-analysis.git
# !git checkout -b main
# Out:
# Reinitialized existing Git repository in /content/exploratory-data-analysis/.git/
# error: remote origin already exists.
# Switched to a new branch 'main'

# %%
# !git add .
# !git commit -m "Add EDA notebook"
# !git push -u origin main
# Out:
# On branch main
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/prince545/exploratory-data-analysis.git'

# %%
# %cd /content/exploratory-data-analysis
# Out:
# /content/exploratory-data-analysis

# %%
# !cp /content/Churn_Modelling.csv/content/exploratory-data-analysis/
# Out:
# cp: missing destination file operand after '/content/Churn_Modelling.csv/content/exploratory-data-analysis/'
# Try 'cp --help' for more information.

# %%
# !cp /content/Untitled5.ipynb.ipynb /content/exploratory-data-analysis/
# Out:
# cp: cannot stat '/content/Untitled5.ipynb.ipynb': No such file or directory

# %%
# %cd /content/exploratory-data-analysis
# Out:
# /content/exploratory-data-analysis

# %%
# !cp /content/eda_notebook.ipynb .
    # !cp /content/Churn_Modelling.csv .
# Out:
#   File "/tmp/ipython-input-67-1168074941.py", line 2
#     get_ipython().system('cp /content/Churn_Modelling.csv .')
#     ^
# IndentationError: unexpected indent

# %%
# !git add .

# %%
# !git commit -m "Add EDA notebook and data"
# Out:
# On branch main
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git push origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/prince545/exploratory-data-analysis.git'

# %%
# !git push origin main --force
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/prince545/exploratory-data-analysis.git'

# %%
# !find /content -name "*.ipynb"

# %%
# !ls /content/*.ipynb
# Out:
# ls: cannot access '/content/*.ipynb': No such file or directory
